# %%
a = 10
b = 20
result = a+b
print(result,type(result))
# print(a + b)
# 출력 => 1020

# %% [markdown]
# a = '3'
# b = '6'
# d = int (a)
# e = int (b)
# result = d+e
# print(result)
# # print(a + b)
# # 출력 => 9

# %%
a = '5.1'
b = '6.1'
c = float(a)
d = float(b)
print(c + d)

# print(a + b)
# 출력 9.2

# %%
age = 22

print("== 정답 v1 ==")

if age >= 20: # 조건이 참이면
  print("성인입니다.") # 실행

if age < 20: # 조건이 참이면
  print("미성년입니다.") # 실행

print("== 정답 v2 ==")

if age >= 20: # 이게 참이면
  print("성인입니다.") # 이게 실행
elif age < 20: # 이게 참이면
  print("미성년입니다.") # 이게 실행

print("== 정답 v3 ==")

if age >= 20: # 조건이 체크
  print("성인입니다.") # 참이면 실행
else:
  print("미성년입니다.") # 거짓이면 실행

# %%
# 문제 : 사용자에게 숫자 3개를 입력받아서, 더한 결과를 출력해주세요. map, strip를 사용해주세요.

print("숫자 3개를 `,`로 구분지어서 입력해주세요.")
print("EX : 10,20,30")
print("입력 : ", end = '') # end = '' => 줄바꿈 안함
a, b, c = map(int, input().strip().split(','))

print("a : {}".format(a))
print("b : {}".format(b))
print("c : {}".format(c))
print("a + b + c : {}".format(a + b + c))

# %%
# 문제 : 실행되는 출력문에는 `참` 그렇지 않으면 `거짓` 이라고 적어주세요.
# 조건 : `참1`, `참2`, `거짓1` 이런 순으로 적어주세요.

# 개념시작
if ( True ):
  print("참")
    
if ( False ):
  print("거짓")
# 개념끝

# 문제시작
a = 10

# `==` => 같다.
if ( a == 10 ):
  print("참 1")

# `!=` => 같지 않다.
if ( a != 10 ):
  print("거짓 1")

if ( a > 10 ):
  print("거짓 2")

if ( a >= 10 ):
  print("참 2")

b = 10

if ( a == b ):
  print("참 3")

# c 에는 true or false 이 담긴다.
c = a != b  # C = False

if ( c ):
  print("기다려")

if ( c == False ):
  print("참 A")

# `not` => 반전
if ( not c ):
  print("참 B")

if ( not(not c) ):
  print("참 C")

d = True

if ( c != d ):
  print("D 거짓")

if ( 10 > 5 and -6 > -10 and 10 != 10 ):
  print("다중 거짓")

if ( 10 < 5 and -6 < -10 and 10 != 10 or 10 > 5 ):
  print("당연 거짓")
# 문제끝
# 참과 거짓을 하나씩 참고하여 다시 풀어 볼 것

# %%
# 문제 : 10대, 20대, 30대 중 나이에 맞는 변수를 출력해주세요.

age = 30 # 25로 바꿔서 실행해보세요. 15로도 바꿔서 실행해보세요.

if (age >= 10 and age <=19):
  print("10대")
if (age >= 20 and age <=29):
  print("20대")
else :    
  print("30대")

# %%
# 문제 : 할인 대상인지 아닌지 출력해주세요.
# 조건 : 나이가 19세 이하이거나 60세 이상이면 할인 대상입니다.
# 조건 : `and, or`없이 풀어야 합니다.
# 조건 : 2가지 이상의 방법으로 풀어야 합니다.

age = 33

if (age <= 19)
    print("== 정답 v1 ==")
print("할인 대상입니다.")
print("할인 대상이 아닙니다.")

print("== 정답 v2 ==")
print("할인 대상입니다.")
print("할인 대상이 아닙니다.")

# %%
i = 1   # 1 ~ 300까지 5씩 증가하는 숫자를 나열하라.

while i <= 300:
  print(i)
  i += 5

# %%
# 문제 : 30부터 -5까지 출력해주세요.

i = 20

while i >= -10:
  print(i)
  i -= 5  #5개씩 감소하는 것, 2씩 감소한다면 i= i-2 (i -= 2)

# %%
# 문제 : 1부터 20 사이의 짝수만 출력해주세요.(개념 : while, if, %)

print("== 정답 v1 ==")

i = 2
while ( i <= 20 ):
  print(i)
  i += 2

print("== 정답 v2 ==")

i = 1
while ( i <= 20 ):
  if ( i % 2 == 0 ):  # == 의 의미 = 나머지가 0 이라는 뜻임
    print(i)
  i += 1

# %%
# 문제 : 1부터 30 사이의 수 중에서 3의 배수만 출력해주세요.

i = 1
while ( i <= 30 ):
  if ( i % 3 == 0 ):
    print(i)
  i += 1

# %%
# 문제 : 1부터 10까지의 합을 출력해주세요.(개념 : while)

sum = 0    # sum = 1
i = 1

while i <= 10:
  sum += i
  i += 1

print(sum)

# %%
# 문제 : 1부터 100까지의 수 중에서 짝수의 합을 출력해주세요.

print("== 정답 v1 ==")

sum = 0
i = 2

while i <= 100:
  sum += i
  i += 2

print("1부터 100사이의 짝수의 합 : {}".format(sum))

print("== 정답 v2 ==")

sum = 0
i = 1

while i <= 100:
  if i % 2 == 0:
    sum += i
  i += 1

print("1부터 100사이의 짝수의 합 : {}".format(sum))

# %%
i = 1
while i <= 10:   #10회 반복
  
  # 여기부터
  j = 1
  while j <= 3:
    print(j)
    j += 1
  print("---")
  # 여기까지가 10번 반복된다.

  i += 1

# %%
i = 1
while i <= 10:
  
  # 여기부터
  j = 1
  while j <= 3:
    print(j, end='')
    j += 1
  print("---")
  # 여기까지가 10번 반복된다.

  i += 1

# %%
# 문제 : for문으로 1부터 100까지 출력
for i in range(1, 101,1):    # range(시작, 끝-1, 보폭), 보폭을 생략하면 1씩 증가함

# %%
# 문제 : for문으로 100부터 1까지 출력

for i in range(100, 0, -10):
  print(i)

# %%
# 문제 : for문으로 구구단 1단 ~ 9단 출력
for dan in range(1, 10):              # for dan in range(1, 10, 2)등으로 변경해 볼 것.
  print("# {}단 #".format(dan))      #  print(f"# {}단 #") 으로 대치 가능

  for i in range(1, 10):
    print("{} * {} = {}".format(dan, i, dan * i))

# %%
def a():
  for i in range(1, 11):
   print(i)
a()

# %%
def aa():
  
 dan = 8 
i = 1
while i <= 9:
  print("{} * {} = {}".format(dan, i, dan * i))
  i += 1

  aa()

# %%
# 문제 : 입력받은 정수가 소수인지 아닌지 알려주는 함수를 구현해주세요.

def get_divisors_sum(num):
  s = 0
  i = 1
  while i <= num:
    if num % i == 0:
      s += i
    i += 1
  return s

def is_prime_number(num):
  if num == 1:
    return False

  i = 2
  while i < num:
    if num % i == 0:
      return False
    i += 1
    
  return True

def is_prime_number_v2(num):
  return get_divisors_sum(num) == num + 1

print("3은 소수입니다 : {}".format(is_prime_number(3)))
print("4는 소수입니다 : {}".format(is_prime_number(4)))
print("1000은 소수입니다 : {}".format(is_prime_number(1000)))

# %%
# 문제 : 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. '화'가 리스트 안에 들어있는지 알려주세요.

a = ['월', '화', '수', '목', '금']

if '화' in a:
  print("있네요!")
else:
  print("없네요!")

# %%
# 문제 : 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. '화'가 리스트 안에서 몇 번째 데이터 인지 알려주세요.

a = ['월', '화', '수', '목', '금']

i = a.index('화')

print(i)

# %%
# 문제 : 리스트에 순서대로 '월', '화', '수', '목', '금'을 한번에 담아주세요. 리스트에 있는 '금'을 삭제하는 3가지 방법을 보여주세요.

a = ['월', '화', '수', '목', '금']

# del a[4] # 정답 v1
# del a[-1] # 정답 v1
# del a[a.index('금')] # 정답 v2
# if '금' in a:         코드 검토 요
a.remove('금') # 정답 v3

print(a)

# %%
'''
문제 : 딕셔너리에 각 달의 마지막 날들을 한번에 담기
조건 : 1월 ~ 3월까지
조건 : 2월의 마지막은 28일로 함
조건 : 첫 데이터의 key는 "1월", value는 31
'''
month_end_days = {"1월":31, "2월":28, "3월":31} # 딕셔너리는 중괄호{}를 사용, 리스트는 대괄호 []로 사용
print(month_end_days)

# %%
print("== 정답 v1 ==")
month_end_days = {}

month_end_days["1월"] = 31
month_end_days["2월"] = 28
month_end_days["3월"] = 31

print(month_end_days)

print("== 정답 v2 ==")
month_end_days = {}

for i in range(1, 12 + 1):
  month = str(i) + "월"

  end_day = 31

  if i == 2:
    end_day = 28
  elif i in [4, 6, 9, 11]:
    end_day = 30

  month_end_days[month] = end_day

print(month_end_days)

print("== 정답 v3 ==")
month_end_days = {}

month_end_days_list_ver = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

for i, end_day in enumerate(month_end_days_list_ver):  # enumerate : 2가지의 값을 한번에 가져 오는 함수
  month = str(i + 1) + "월"
  month_end_days[month] = end_day

print(month_end_days)
