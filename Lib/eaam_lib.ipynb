# %%
# 수학모듈
# 수학 계산기능을 제공하는 모듈
# 제곱근, 삼각함수, 원주율등을 포함

import math # 16의 제곱근 계산
print(math. sqrt(16))
# Out:
# 4.0

# %%
# 난수 모듈
# 무작위값을 생성하는 모듈
#게임, 추첨, 테스트 데이터에 사용

import random

# 1부터 100까지 중 랜던한 숫자 1개 출력
print(random.randint(1,100))
# Out:
# 85

# %%
# 날자 시간 모듈
# 날자와 시간을 다루는 모듈
# 현재시간 확인, 날자 계산 사용

import datetime

# 현재 날자와 시간을 출력
print(datetime.datetime.now())
# Out:
# 2026-03-13 12:05:12.857994

# %%
# 자료구조 모듈
# 자료 구조를 편하게 쓰도록 도와줌
# 카운트, 큐, 딕셔너리 확장 기능 제공

# 만자열에서 각 글자의 갯수를 셈
from collections import Counter
print(Counter('apple'))
# Out:
# Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1})

# %%
# 시간 제어 모듈
# 시간 흐름을 제어하는 모둘
# 프로그램을 잠시 멈출때 사용

import time

# 프로그램을 3초동안 멈춤

time. sleep(3)

# 3초가 지난후 실행
print("3초후 실행")
# Out:
# 3초후 실행

# %%
# 시스템 ㅁㅎ듈
# 파이썬 실행 환경울 다루는ㅌ 모듈
# 버전확인, 프로그램 종료 사용

import sys

#현재 사용중인 파이썬 버전 출력
print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
# 운영체제 (OS) 모듈
# 운영체제와 관련된 기능 제공
# 파일/폴더 경로 처리에 사용

import os
#현재 작업중인 폴더 경로 출력
print(os.getcwd())
# Out:
# c:\work\py_ex_2603\Lib

# %%
# 데이터 형식 모듈
# json 형식으로 데이터를 변환
# - Josn : 데이터를 약속된 형식으로 적는 방식 ("key. : "value)
# 웹, API 파일 저장에 이용
# - API : 프로그램끼리 대화하는 방법/ 규칙
import json

data = {
    "name" : "jin",
    "age" : 22
}
print(json.dumps(data))
# Out:
# {"name": "jin", "age": 22}

# %%
# 정규표현식 모듈
# 문자열 패턴 감사 모듈
# 형식 확인 (아이디, 이메일등)에 사용

import re

# 문자열이 'hi'로 시작하는지 확인
print(bool(re.match('hi', 'hi python')))
# Out:
# True

# %%
# csv 파일 모듈
# csv (엑셀) 파일을 읽고 쓰는 모듈
# 데이터 저장/분석 기초에 사용
# 해당 경로에 .csv 파일이 생성됨

# csv 파일에 한줄 데이터를 저장
import csv
with open('test.csv', 'w', newline='') as f: csv. writer(f).writerow(['name', 'score'])
